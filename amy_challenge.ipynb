# %%
#Tech challenge
# NYC Collision data

# %%
#Imports:
import pandas as pd
from sklearn import linear_model

import random
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import math 
import os
sns.set_style('darkgrid')  

 
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the data as pd
df_1 = pd.read_csv('NYPD_Motor_Vehicle_Collisions.csv')

# %%
# EDA

# %%
# check data
df_1.head()
# Out:
#          DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  04/30/2019  0:00   BROOKLYN    11222  40.727184 -73.950700
# 1  04/30/2019  0:00  MANHATTAN    10075  40.776318 -73.962135
# 2  04/30/2019  0:00     QUEENS    11354  40.763283 -73.830710
# 3  04/30/2019  0:00     QUEENS    11412  40.705240 -73.775080
# 4  04/30/2019  0:00        NaN      NaN  40.593525 -73.996280
#
#                   LOCATION                    ON STREET NAME  \
# 0    (40.727184, -73.9507)                               NaN
# 1  (40.776318, -73.962135)  EAST 79 STREET
# 2   (40.763283, -73.83071)                               NaN
# 3    (40.70524, -73.77508)  LIBERTY AVENUE
# 4   (40.593525, -73.99628)  BELT PARKWAY
#
#   CROSS STREET NAME                           OFF STREET NAME  ...  \
# 0               NaN  236       ECKFORD STREET                  ...
# 1    MADISON AVENUE                                       NaN  ...
# 2               NaN  137-17    NORTHERN BOULEVARD              ...
# ...

# %%
df_1.describe().T
# Out:
#                                    count          mean           std  \
# LATITUDE                       1300856.0  4.069345e+01  1.111570e+00
# LONGITUDE                      1300856.0 -7.387725e+01  2.324406e+00
# NUMBER OF PERSONS INJURED      1487366.0  2.594721e-01  6.572958e-01
# NUMBER OF PERSONS KILLED       1487352.0  1.165158e-03  3.616187e-02
# NUMBER OF PEDESTRIANS INJURED  1487383.0  5.098149e-02  2.326804e-01
# NUMBER OF PEDESTRIANS KILLED   1487383.0  6.346718e-04  2.581745e-02
# NUMBER OF CYCLIST INJURED      1487383.0  2.033437e-02  1.422942e-01
# NUMBER OF CYCLIST KILLED       1487383.0  7.866165e-05  8.944281e-03
# NUMBER OF MOTORIST INJURED     1487383.0  1.883120e-01  6.191295e-01
# NUMBER OF MOTORIST KILLED      1487383.0  4.544895e-04  2.321628e-02
# UNIQUE KEY                     1487383.0  2.662150e+06  1.508736e+06
#
#                                      min            25%           50%  \
# ...

# %%
# # SORT FILE 1 by date
df_1 = df_1.sort_index(by=['DATE'], ascending=[True])

# %%
df_1['year_2019'] = 0

for ro in range(len(df_1)):
    if "2019" in df_1.loc[ro, 'DATE']: 
        df_1.loc[ro, 'year_2019'] = 1 
df_1['year_2019'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-94f2977650fe> in <module>
#       3 for ro in range(len(df_1)):
#       4     if "2019" in df_1.loc[ro, 'DATE']:
# ----> 5         df_1.loc[ro, 'year_2019'] = 1
#       6 df_1['year_2019'].value_counts()
#       7
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     618                 # scalar
#     619                 for item in labels:
# --> 620                     setter(item, value)
#     621
# ...

# %%
df_1.head()
# Out:
#                DATE   TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 1360118  01/01/2013   4:00        NaN      NaN        NaN        NaN
# 1386627  01/01/2013  16:45   BROOKLYN    11234  40.583728 -73.893712
# 1386628  01/01/2013  16:50   BROOKLYN    11228  40.608378 -74.009079
# 1386629  01/01/2013  16:50  MANHATTAN    10022  40.760928 -73.969133
# 1386630  01/01/2013  17:00  MANHATTAN    10022  40.760928 -73.969133
#
#                           LOCATION                    ON STREET NAME  \
# 1360118                        NaN                               NaN
# 1386627  (40.5837275, -73.8937121)  FLATBUSH AVENUE
# 1386628  (40.6083779, -74.0090794)  BENSON AVENUE
# 1386629   (40.7609285, -73.969133)  EAST 57 STREET
# 1386630   (40.7609285, -73.969133)  EAST 57 STREET
#
#                         CROSS STREET NAME OFF STREET NAME  ...  \
# 1360118                               NaN             NaN  ...
# 1386627  AVIATION ROAD                                NaN  ...
# ...

# %%
# KEEP ONLY DATES AFTER 12-31-2018 -CHECK IF THIS DROPS CORRECTLY!!
df = df_1.loc[df.index < '01-01-2019']
# data['date'] = data['date'].apply(dateutil.parser.parse, dayfirst=True) - check this!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-76657b6e32de> in <module>
#       1 # KEEP ONLY DATES AFTER 12-31-2018 -CHECK IF THIS DROPS CORRECTLY!!
# ----> 2 df = df_1.loc[df.index < '01-01-2019']
#       3 # data['date'] = data['date'].apply(dateutil.parser.parse, dayfirst=True) - check this!
#
# TypeError: '<' not supported between instances of 'builtin_function_or_method' and 'str'

# %%
from datetime import datetime
# datetime.datetime.strptime('03-11-12', '%d-%m-%y').date()
# datetime.datetime.strptime(df_1['DATE'], '%m-%d-%y').date()
# datetime.date(2012, 11, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-916f2af74fe5> in <module>
#       2 # datetime.datetime.strptime('03-11-12', '%d-%m-%y').date()
#       3 # datetime.datetime.strptime(df_1['DATE'], '%m-%d-%y').date()
# ----> 4 datetime.date(2012, 11, 3)
#
# TypeError: descriptor 'date' requires a 'datetime.datetime' object but received a 'int'

# %%
from datetime import datetime
datetime_object = datetime.strptime('4/30/2019 ','%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-592cd0f2fa37> in <module>
#       1 from datetime import datetime
# ----> 2 datetime_object = datetime.strptime('4/30/2019 ','%m/%d/%Y')
#
# ~/anaconda3/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# ~/anaconda3/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     360     if len(data_string) != found.end():
#     361         raise ValueError("unconverted data remains: %s" %
# --> 362                           data_string[found.end():])
#     363
#     364     iso_year = year = None
#
# ...

# %%
# from datetime import datetime
import datetime

# datetime.date('2012-02-10' , '%Y-%m-%d')
# datetime.datetime.strptime('24052010', "%d%m%Y").date()
# datetime.datetime.strptime(df.date, "%d%m%Y").date()

datetime.datetime.strptime(df_1['DATE'], "%m-%d-%Y")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-74a2ae21f41e> in <module>
#       6 # datetime.datetime.strptime(df.date, "%d%m%Y").date()
#       7
# ----> 8 datetime.datetime.strptime(df_1['DATE'], "%m-%d-%Y")
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
import datetime

# x = datetime.datetime(2018, 9, 15)

x = datetime.datetime(df_1.DATE)

print(x.strftime("%b %d %Y"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9bdd24854d65> in <module>
#       3 # x = datetime.datetime(2018, 9, 15)
#       4
# ----> 5 x = datetime.datetime(df_1.DATE)
#       6
#       7 print(x.strftime("%b %d %Y"))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#      91             return converter(self.iloc[0])
#      92         raise TypeError("cannot convert the series to "
# ---> 93                         "{0}".format(str(converter)))
#      94
#      95     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'int'>

# %%
# datestring = "2008-12-12 19:21:10"
datestring = df_1.DATE
dt = datetime.strptime(datestring, '%m-%d-%Y')
print (dt.year, dt.month, dt.day)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-b3b71b376e11> in <module>
#       1 # datestring = "2008-12-12 19:21:10"
#       2 datestring = df_1.DATE
# ----> 3 dt = datetime.strptime(datestring, '%m-%d-%Y')
#       4 print (dt.year, dt.month, dt.day)
#
# AttributeError: module 'datetime' has no attribute 'strptime'

# %%
from datetime import datetime
datetime.strptime(df_1['date'], "%m-%d-%y")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-d2f7a45aa7cd> in <module>
#       1 from datetime import datetime
# ...

# %%
def from_string(date, formatting):
    return datetime.datetime.strptime(date, formatting)

# %%
from dateutil.parser import parse
df_1['new_dates'] = 0
df_1['new_dates'] = df_1['DATE']
[datetime.strptime(x, '%m/%d/%Y') for x in df_1['new_dates']]
# Out:
# [datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 1, 1, 0, 0),
# ...

# %%
pd.to_datetime(df_1['DATE'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime._string_to_dts()
#
# ValueError: Error parsing datetime string "08/04/2015" at position 2
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-d87c07a67334> in <module>
# ----> 1 pd.to_datetime(df_1['DATE'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     590         else:
#     591             from pandas import Series
# --> 592             values = convert_listlike(arg._values, True, format)
# ...

# %%
df_good = pd.to_datetime(df_1['new_dates'])

# %%
# CHECK DATES
df_good.head()

# %%
# KEEP ONLY DATES AFTER 12-31-2018
df = df_good.loc[df_good.index < pd.to_datetime('2019-01-01')]

# %%
df_good['year_2019'] = 0

for ro in range(len(df_good)):
    if "2019" in df_good.loc[ro, 'DATE']: 
        df_good.loc[ro, 'year_2019'] = 1 
df_good['year_2019'].value_counts()

# %%
# CHECK DATES
df_good.head()

# %%
df_good.tail()

# %%
df_good.shape

# %%
# # SORT FILE 2 by stop id
# df_2 = df_2.sort_index(by=['stop_id'], ascending=[True])

# %%
df_good.dtypes

# %%
# Save csv
df_good.to_csv("df_nyc.csv", index=False)

# %%
df_1
